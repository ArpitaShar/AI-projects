# %%
import pandas as pd
import numpy as np

# %%
df_DemRegister = pd.read_csv('../Data/MG_DemRegister_Panch2223.csv', delimiter='|')
df_Location_Master = pd.read_csv('../Data/MG_MGNREGA_LocationMaster.csv', delimiter='|')
df_MIS_Register = pd.read_csv('../Data/MG_MISDemRegister_Panch2223.csv', delimiter='|')
df_WRKDTLCMP_2223_to_2526 = pd.read_csv('../Data/MG_WRKDTLCMP_2223_to_2526.csv', delimiter='|')
# Out:
# /tmp/ipykernel_580563/564437977.py:4: DtypeWarning: Columns (4,177,183,185,348) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_WRKDTLCMP_2223_to_2526 = pd.read_csv('../Data/MG_WRKDTLCMP_2223_to_2526.csv', delimiter='|')

# %%
df_DemRegister.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6447 entries, 0 to 6446
# Data columns (total 51 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   STate_code           6447 non-null   int64
#  1   District_code        6447 non-null   int64
#  2   Block_Code           6447 non-null   int64
#  3   Panchayat_code       6447 non-null   int64
#  4   RegHH                6339 non-null   float64
#  5   RegP                 6339 non-null   float64
#  6   EDH                  5861 non-null   float64
#  7   EDP                  5861 non-null   float64
#  8   EOfH                 5857 non-null   float64
#  9   EofP                 5857 non-null   float64
#  10  EProH                6447 non-null   int64
#  11  EProP                6447 non-null   int64
#  12  MustFill             5805 non-null   float64
#  13  F100Days             1792 non-null   float64
#  14  OnGWorks             0 non-null      float64
# ...

# %%
df_MIS_Register.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6447 entries, 0 to 6446
# Data columns (total 68 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   STate_code            6447 non-null   int64
#  1   District_code         6447 non-null   int64
#  2   Block_Code            6447 non-null   int64
#  3   Panchayat_code        6447 non-null   int64
#  4   fin_year              0 non-null      float64
#  5   unmetdmd_hh           0 non-null      float64
#  6   unmetdmd_app          0 non-null      float64
#  7   unmetdmd_day          0 non-null      float64
#  8   delayalloc_hh         0 non-null      float64
#  9   delayalloc_app        0 non-null      float64
#  10  delayalloc_day        0 non-null      float64
#  11  delaypay_nomust       0 non-null      float64
#  12  delaypay_amt          0 non-null      float64
#  13  unemp_allowpaidday    0 non-null      float64
# ...

# %%
df_Location_Master.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6456 entries, 0 to 6455
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   STATE_CODE        6456 non-null   int64
#  1   STATE_NAME        6456 non-null   object
#  2   DISTRICT_CODE     6456 non-null   int64
#  3   DISTRICT_NAME     6456 non-null   object
#  4   BLOCK_CODE        6456 non-null   int64
#  5   BLOCK_NAME        6456 non-null   object
#  6   PANCHAYAT_CODE    6456 non-null   int64
#  7   PANCHAYAT_NAME    6456 non-null   object
#  8   VILLAGE_CODE      6456 non-null   int64
#  9   VILLAGE_NAME      6456 non-null   object
#  10  LGD_ST_Code       6456 non-null   int64
#  11  LGD_ST_Name       6456 non-null   object
#  12  LGD_Dist_Code     6456 non-null   int64
#  13  LGD_Dist_Name     6456 non-null   object
#  14  LGD_Block_Code    6456 non-null   int64
#  15  LGD_Block_Name    5967 non-null   object
# ...

# %%
df_WRKDTLCMP_2223_to_2526.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 220484 entries, 0 to 220483
# Columns: 369 entries, panchayat_code to Exp_cost_Material
# dtypes: float64(113), int64(211), object(45)
# memory usage: 620.7+ MB

# %%
df_WRKDTLCMP_2223_to_2526.head()
# Out:
#    panchayat_code                 work_code  \
# 0      2101006001   2101006001/DP/GIS/27183
# 1      2101006001       2101006001/LD/19474
# 2      2101006002   2101006002/DP/GIS/25406
# 3      2101006002   2101006002/DP/GIS/25419
# 4      2101006002  2101006002/IF/IAY/159159
#
#                                            work_name work_cat_code workstatus  \
# 0  Tree Plantation at Amdoh VEC in convergence wi...            DP         05
# 1  Construction of Kitchen Garden at Amdoh VEC WO...            LD         03
# 2  Tree Plantation in convergence with SHG at Amj...            DP         03
# 3  Tree Plantation in convergence with SHG at Amj...            DP         03
# 4  Construction of PMAY-G House for Individuals -...            IF         06
#
#    Exe_Agency_code Exe_level_code  sanc_tech_Contingency  \
# 0                3             GP                    0.0
# 1                3             GP                    0.0
# ...

# %%
df_WRKDTLCMP_2223_to_2526.columns
# Out:
# Index(['panchayat_code', 'work_code', 'work_name', 'work_cat_code',
#        'workstatus', 'Exe_Agency_code', 'Exe_level_code',
#        'sanc_tech_Contingency', 'sanc_tech_labr_unskilled',
#        'sanc_tech_labr_semiskilled',
#        ...
#        'Semiskilled2526', 'Skill2526', 'tot_cash_all2526', 'tot_lab',
#        'tot_mat', 'tot_cntpds', 'tot_semiskilled', 'tot_skill', 'tot_cntmsr',
#        'Exp_cost_Material'],
#       dtype='object', length=369)

# %%
print(df_DemRegister.shape)
print(df_MIS_Register.shape)
print(df_Location_Master.shape)
print(df_WRKDTLCMP_2223_to_2526.shape)
# Out:
# (6447, 51)
# (6447, 68)
# (6456, 20)
# (220484, 369)
