# %%
[DEFAULT]
user=ocid1.user.oc1..aaaaaaaatkenzllfdvussxlm34pi4bldouu2e7x63irgcbm6jfgeipphbs3a
fingerprint=15:0b:d3:66:08:10:1e:a5:d3:0d:07:5b:9e:f5:d0:0d
tenancy=ocid1.tenancy.oc1..aaaaaaaaw4cnicfnbtyrckdaejaxud3dpmqbzxu2yrkq2kftgeq4ezibretq
region=ap-mumbai-1
key_file=<path to your private keyfile> # TODO

###############
[DEFAULT]
user=ocid1.user.oc1..aaaaaaaatkenzllfdvussxlm34pi4bldouu2e7x63irgcbm6jfgeipphbs3a
fingerprint=37:bc:31:f1:81:e6:d2:e0:e1:32:bf:01:b2:6e:f3:42
tenancy=ocid1.tenancy.oc1..aaaaaaaaw4cnicfnbtyrckdaejaxud3dpmqbzxu2yrkq2kftgeq4ezibretq
region=ap-mumbai-1
key_file=<path to your private keyfile> # TODO

# %%
import requests
import json

# %%
# Replace with your actual API Gateway endpoint
url = "https://c6azw2ouritt6iqezyvncfwdee.apigateway.ap-mumbai-1.oci.customer-oci.com/v1"

# Your input payload
# payload = {
#     "message": "Hello from Python client"
# }

# Headers
headers = {
    "Content-Type": "application/json"
}

# POST request
response = requests.post(url, headers=headers)

# Print the response
print("Status Code:", response.status_code)
print("Response Body:", response.text)
# Out:
# Status Code: 404
# Response Body: {"code":404,"message":"Not Found"}
